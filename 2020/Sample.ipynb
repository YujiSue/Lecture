# %% [markdown]
# ##サンプルコード集
# ここにあるコードは、基本的なPythonのコードです。
# これらをテンプレートにして、上手く組み合わせてコピペしながら課題に取り組んでください。
# <font color="magenta">※\#から始まる文は注釈・コメントです。実際にプログラムを書くのに利用するときは、\#から始まる部分はコピーしないでください。</font>

# %% [markdown]
# ##まずは基本となる計算からです。

# %%
#数値を扱う
数字１=100 #○○={値}の形で表します。この○○を「変数」といいます。※イコール以降は半角英数字でなくではいけません。
数字２=-20 #こうやって一度「変数」の中に数値を保存します。そうしないとコンピュータが数値を忘れてしまいます。
数字３=1.5 
#基本計算
#足し算
数字４=数字１+数字２ #{結果を保存する変数}={値１}+{値２}の形で表します。※イコールとプラス記号は半角英数字でなくではいけません。
print("数字１＋数字２＝",数字４) #結果表示

#引き算
数字５=数字１-数字２ #{結果を保存する変数}={値１}-{値２}の形で表します。※イコールとマイナス記号は半角英数字でなくではいけません。
print("数字１ー数字２＝",数字５) #結果表示

#かけ算
数字６=数字１*数字３ #{結果を保存する変数}={値１}*{値２}の形で表します。※イコールとアスタリスク（＊）記号は半角英数字でなくではいけません。
print("数字１×数字３＝",数字６) #結果表示

#割り算
数字７=数字２/数字３ #{結果を保存する変数}={値１}/{値２}の形で表します。※イコールとスラッシュ（／）記号は半角英数字でなくではいけません。
print("数字２÷数字３＝",数字７) #結果表示
# Out:
# 数字１＋数字２＝ 80
# 数字１ー数字２＝ 120
# 数字１×数字３＝ 150.0
# 数字２÷数字３＝ -13.333333333333334

# %% [markdown]
# ##続いて文字と文章いってみましょう。
