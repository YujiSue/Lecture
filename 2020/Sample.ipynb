# %% [markdown]
# <a href="https://colab.research.google.com/github/YujiSue/Lecture/blob/master/2020/Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##サンプルコード集
# ここにあるコードは、基本的なPythonの説明とコード例です。
# これらをテンプレートにして、上手く組み合わせてコピペしながら課題に取り組んでください。
# <font color="magenta">※\#から始まる文は注釈・コメントです。なくても作動します。</font>

# %% [markdown]
# ##まずは基本となる計算からです。

# %%
#数値を扱う
数字１=100 #○○={値}の形で表します。この○○を「変数」といいます。
数字２=-20 #※イコール以降は半角英数字でなくではいけません。
数字３=1.5 #こうやってコンピュータが数値を忘れないように一度「変数」の中に数値を保存します。

#基本計算
#足し算は{結果を保存する変数}={値１}+{値２}の形で表します。
数字４=数字１+数字２ #※イコールとプラス記号は半角英数字でなくではいけません。
#結果表示
print("数字１＋数字２＝",数字４) 

#引き算は{結果を保存する変数}={値１}-{値２}の形で表します。
数字５=数字１-数字２ #※イコールとマイナス記号は半角英数字でなくではいけません。
#結果表示
print("数字１ー数字２＝",数字５) 

#かけ算は{結果を保存する変数}={値１}*{値２}の形で表します。
数字６=数字１*数字３ #※イコールとアスタリスク（＊）記号は半角英数字でなくではいけません。
#結果表示
print("数字１×数字３＝",数字６) 

#割り算は{結果を保存する変数}={値１}/{値２}の形で表します。
数字７=数字２/数字３ #※イコールとスラッシュ（／）記号は半角英数字でなくではいけません。
#結果表示
print("数字２÷数字３＝",数字７)
# Out:
# 数字１＋数字２＝ 80
# 数字１ー数字２＝ 120
# 数字１×数字３＝ 150.0
# 数字２÷数字３＝ -13.333333333333334

# %% [markdown]
# ##続いて文字と文章のサンプルです。

# %%
#文字を扱う
文字１='いろはにほへと' #数字を扱うときと基本形は同じで、○○={値}の形で表します。
print('文字１：', 文字１)
文字２='ちりぬるを' #一か所違うのは、文字の場合''（引用符）で囲う必要があります。
print('文字２：', 文字２)
#異なる文字同士をつなぐ場合は、
文字３=文字１+文字２ #このように足し算でつなぎます。※イコールとプラス記号は半角です。
print('文字１と文字２を連結：', 文字３)

#なぜ文字の場合は引用符で囲うのか、下の例で説明します。
#例えば、学校のクラスを表記するときによく 「1-1」とか「5-2」みたいな表記をします。
#もし文字を引用符で囲わないと、以下のような現象が発生します。
クラス１= 5-2
クラス２='5-2'
print('クラス１：', クラス１) #実行すると「３」と表示される
print('クラス２：', クラス２) #実行すると「5-2」と表示される。

#お分かりいただけただろうか...
#要するに、日常で数字が出てきたときに、そのまま数字として認識したい場合と、
#文字として認識したい場合があるわけです。
#私たちは無意識のうちに前後の文脈から判断しているけれど、コンピュータにはきちんと
#数字と文字の使い分けを指示してあげないと、伝わらないわけです。
#そして文字として認識するようにコンピュータに指示する方法が、引用符で囲むという操作になります。

#ほかにも以下のような場合、数字と認識するか、文字として認識するかで結果が変わってしまいますね。
print(100+1,"匹の犬")
print('100+1','匹の犬')
# Out:
# 文字１： いろはにほへと
# 文字２： ちりぬるを
# 文字１と文字２を連結： いろはにほへとちりぬるを
# クラス１： 3
# クラス２： 5-2
# 101 匹の犬
# 100+1 匹の犬
