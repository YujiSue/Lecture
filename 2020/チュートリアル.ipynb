# %% [markdown]
# ##<font color="skyblue">【チュートリアル】</font>
# ここでは実際にPythonのプログラミングを実行してもらいます。
# といっても難しいことはありません。
# このブロックの下に
# ```python:sample
# import numpy as np
# ```
# という文書で始まるブロックが見えていますね？
#
# 1.   まずはその<font color="red">import</font> と書かれた辺りをクリックしてみてください。
# 2.   次に左上隅に <img alt="▶︎" src="https://drive.google.com/file/d/1DOtMhlq74ZiTd70R2BjgHrqXI2H6SYQx/view?usp=sharin">
# マークが出るので、それをクリックしてみてください。

# %%
import numpy as np

print('サンプルコードを作るよ')
# Out:
# サンプルコードを作るよ
